# %% [markdown]
# #If you had to move to Canada, where would it be safer to live?

# %% [markdown]
# Every year, more and more people (students, workers, refugees, etc.) migrate to Canada. Over time, Canada has become one of the top choices for relocation due to its safety, quality of life, and multiculturalism.
#
# This analysis aims to find which province in Canada is the safest in order to make an informed decision about moving.
#
# The analysis will primarily focus on the year 2019.
#
# If you wish to explore the other analyses, please refer to the provided "https://github.com/Yaelllll/Portfolio_Data"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/drive/MyDrive/Yael/DEV/0. Projects-Data/5. Crimes-Unemployment Canada/Crimes_report_Canada_2021.csv')

# %%
df.head(3)
# Out:
#       CITY  TOWN Population CSI_Violent %_CHNG_Violent CSI_NoViolent  \
# 0   Toronto   ON  2,794,396        88.3         -2.40%          45.2
# 1  Montréal   QC  1,762,949       105.3         14.60%          59.9
# 2   Calgary   AB  1,305,550          86          6.50%            70
#
#   %_CHNG_NoViolent
# 0           -1.60%
# 1            2.70%
# 2          -13.90%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CITY              521 non-null    object
#  1   TOWN              521 non-null    object
#  2   Population        521 non-null    object
#  3   CSI_Violent       521 non-null    object
#  4   %_CHNG_Violent    521 non-null    object
#  5   CSI_NoViolent     521 non-null    object
#  6   %_CHNG_NoViolent  521 non-null    object
# dtypes: object(7)
# memory usage: 28.6+ KB

# %%
df['CSI_Violent'] = df['CSI_Violent'].str.replace(',', '')
df['CSI_Violent'] = df['CSI_Violent'].astype(np.float)
# Out:
# <ipython-input-360-1eff3207d6b2>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['CSI_Violent'] = df['CSI_Violent'].astype(np.float)

# %%
df['CSI_NoViolent'] = df['CSI_NoViolent'].str.replace(',', '')
df['CSI_NoViolent'] = df['CSI_NoViolent'].astype(float)

# %%
df['%_CHNG_Violent'] = df['%_CHNG_Violent'].str.replace('%', '')
df['%_CHNG_Violent'] = df['%_CHNG_Violent'].astype(np.float)
# Out:
# <ipython-input-362-7bbfd448ebd8>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['%_CHNG_Violent'] = df['%_CHNG_Violent'].astype(np.float)

# %%
df['%_CHNG_NoViolent'] = df['%_CHNG_NoViolent'].str.replace('%', '')
df['%_CHNG_NoViolent'] = df['%_CHNG_NoViolent'].astype(np.float)
# Out:
# <ipython-input-363-5f1739b20318>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df['%_CHNG_NoViolent'] = df['%_CHNG_NoViolent'].astype(np.float)

# %%
df['Population'] = df['Population'].str.replace(',', '')
df['Population'] = df['Population'].astype(int)

# %%
df
# Out:
#                                        CITY  TOWN  Population  CSI_Violent  \
# 0                                    Toronto   ON     2794396         88.3
# 1                                   Montréal   QC     1762949        105.3
# 2                                    Calgary   AB     1305550         86.0
# 3                                     Ottawa   ON     1017449         64.3
# 4                                   Edmonton   AB      981280        123.8
# ..                                       ...  ...         ...          ...
# 516                              Sheshatshiu   NL        1049       1356.6
# 517                 Sault Ste. Marie (Laird)   ON        1047         31.0
# 518  Grenville County (Merrickville-Wolford)   ON        1036         18.6
# 519                                  Manning   AB        1027         59.6
# 520                              St. Andrews   NB        1001         67.5
#
#      %_CHNG_Violent  CSI_NoViolent  %_CHNG_NoViolent
# 0              -2.4           45.2              -1.6
# 1              14.6           59.9               2.7
# 2               6.5           70.0             -13.9
# 3              13.8           45.0              -0.3
# 4              -3.8           99.6             -10.5
# ..              ...            ...               ...
# 516            50.4         1022.6               9.4
# 517           337.4           28.9             -58.1
# 518           -20.7           25.6              58.5
# 519           -48.0          122.1              13.8
# 520           627.7           71.5              12.3
#
# [521 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CITY              521 non-null    object
#  1   TOWN              521 non-null    object
#  2   Population        521 non-null    int64
#  3   CSI_Violent       521 non-null    float64
#  4   %_CHNG_Violent    521 non-null    float64
#  5   CSI_NoViolent     521 non-null    float64
#  6   %_CHNG_NoViolent  521 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 28.6+ KB

# %%
le = LabelEncoder()
df['TOWN_encoded'] = le.fit_transform(df['TOWN'])

correlation = df.corr(method="pearson")
sns.heatmap(correlation,annot=True)
plt.title('Correlation map')
#plt.xlabel('')
#plt.ylabel('')
plt.show()
# Out:
# <ipython-input-367-dabc7eaf9569>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr(method="pearson")

# %%
print("Towns at Canada to study")
print(df['TOWN'].unique())
print("Number of towns to study")
print(df['TOWN'].nunique())
# Out:
# Towns at Canada to study
# ['ON' 'QC' 'AB' 'MB' 'BC' 'NS' 'SK' 'NL' 'NB' 'PEI' 'YT' 'NWT' 'NU']
# Number of towns to study
# 13

# %%
df_grouped = df.groupby('TOWN')['CSI_Violent'].mean().reset_index()
df_sample = df.groupby('TOWN')['Population'].sum().reset_index()
df_grouped['Population'] = df_sample['Population']
df_grouped
# Out:
#    TOWN  CSI_Violent  Population
# 0    AB   135.815909     3323048
# 1    BC   113.189535     3605446
# 2    MB   236.287879      978996
# 3    NB    91.223529      372659
# 4    NL   146.736842      291432
# 5    NS   108.580000      526340
# 6    NU   570.633333       16621
# 7   NWT   410.475000       26803
# 8    ON    84.927097     8448323
# 9   PEI    55.900000       87970
# 10   QC   184.625641     3608721
# 11   SK   259.722222      727177
# 12   YT   266.750000       25605

# %%
df_sorted = df_grouped.sort_values(by='Population', ascending=False)

plt.bar(df_sorted['TOWN'], df_sorted['Population'])
plt.xlabel('TOWN')
plt.ylabel('Population')
plt.title('Population by TOWN')
plt.xticks(rotation=90)

plt.show()

# %%
df_sorted = df_grouped.sort_values(by='CSI_Violent', ascending=False)

plt.bar(df_sorted['TOWN'], df_sorted['CSI_Violent'])
plt.xlabel('TOWN')
plt.ylabel('Crimes reported')
plt.title('Violence average by TOWN')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# As we can see, the provinces with the highest crime rates are NU (Nunavut) and NWT (Northwest Territories). At first glance, this might be alarming and a sign to avoid living there. However, it's important to mention a crucial factor: these two provinces are also among the smallest in Canada.
#
# Most crime surveys and reports do not emphasize the relationship between population size and crime rates. This may not be apparent at first, but what it means is that in a small population, even a small number of crimes can significantly impact the crime rate per capita. For example, if 10 out of 100 people commit a crime, the crime rate appears high. In contrast, in large populations like Ontario or Quebec, this relationship seems less pronounced, with a ratio of something like 10 out of 100,000.
#
# However, in many cases, small provinces like NU (Nunavut) or NWT (Northwest Territories) could still be options to consider for relocation. It's important to note that these are very small cities.
#
# Considering the above, in terms of safety, it would be best to live in **Ontario**. Its large population is reflected in its mega-cities, thriving businesses, multiculturalism, and low crime rate.

# %%
df_unemployment = pd.read_csv('/content/drive/MyDrive/Yael/DEV/0. Projects-Data/5. Crimes-Unemployment Canada/Unemployment_1995-2022.csv')

# %%
df_unemployment.head(2)
# Out:
#    REF_DATE     GEO           DGUID   Educational attainment      UOM  UOM_ID  \
# 0      1995  Canada  2016A000011124  All levels of education  Percent     239
# 1      1995  Canada  2016A000011124    Less than high school  Percent     239
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR  COORDINATE  VALUE STATUS  SYMBOL  \
# 0         units          0  v99916314         1.1   10.6      A     NaN
# 1         units          0  v99916315         1.2   21.2      A     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         1
# 1         NaN         1

# %%
df_unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   REF_DATE                1320 non-null   int64
#  1   GEO                     1320 non-null   object
#  2   DGUID                   1320 non-null   object
#  3   Educational attainment  1320 non-null   object
#  4   UOM                     1320 non-null   object
#  5   UOM_ID                  1320 non-null   int64
#  6   SCALAR_FACTOR           1320 non-null   object
#  7   SCALAR_ID               1320 non-null   int64
#  8   VECTOR                  1320 non-null   object
#  9   COORDINATE              1320 non-null   float64
#  10  VALUE                   1153 non-null   float64
#  11  STATUS                  1320 non-null   object
#  12  SYMBOL                  0 non-null      float64
#  13  TERMINATED              0 non-null      float64
#  14  DECIMALS                1320 non-null   int64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 154.8+ KB

# %%
df_unemployment.drop('DGUID', axis=1, inplace=True)
df_unemployment.drop('UOM', axis=1, inplace=True)
df_unemployment.drop('UOM_ID', axis=1, inplace=True)
df_unemployment.drop('SCALAR_FACTOR', axis=1, inplace=True)
df_unemployment.drop('SCALAR_ID', axis=1, inplace=True)
df_unemployment.drop('COORDINATE', axis=1, inplace=True)
df_unemployment.drop('VECTOR', axis=1, inplace=True)
df_unemployment.drop('STATUS', axis=1, inplace=True)
df_unemployment.drop('SYMBOL', axis=1, inplace=True)
df_unemployment.drop('TERMINATED', axis=1, inplace=True)
df_unemployment.drop('DECIMALS', axis=1, inplace=True)
df_unemployment.head(2)
# Out:
#    REF_DATE     GEO   Educational attainment  VALUE
# 0      1995  Canada  All levels of education   10.6
# 1      1995  Canada    Less than high school   21.2

# %%
df_unemployment = df_unemployment[df_unemployment['Educational attainment'] == "All levels of education"]
df_unemployment['GEO'].unique()
df_unemployment.drop('Educational attainment', axis=1, inplace=True)
# Out:
# <ipython-input-376-e25b2873e8de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unemployment.drop('Educational attainment', axis=1, inplace=True)

# %%
df_unemployment.head(2)
# Out:
#    REF_DATE                        GEO  VALUE
# 0      1995                     Canada   10.6
# 5      1995  Newfoundland and Labrador   21.5

# %%
df_unemployment['GEO'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia'], dtype=object)

# %%
replace_dict = {
    'Alberta': 'AB',
    'British Columbia': 'BC',
    'Manitoba': 'MB',
    'New Brunswick': 'NB',
    'Newfoundland and Labrador': 'NL',
    'Nova Scotia': 'NS',
    'Ontario': 'ON',
    'Prince Edward Island': 'PEI',
    'Quebec': 'QC',
    'Saskatchewan': 'SK'
}
df_unemployment['GEO'] = df_unemployment['GEO'].replace(replace_dict)
df_unemployment.columns = ['YEAR', 'TOWN', 'UNEM_VALUE']
df_unemployment = df_unemployment[df_unemployment['YEAR'] == 2021]
df_unemployment.head(3)
# Out:
# <ipython-input-379-0e148ead14c2>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unemployment['GEO'] = df_unemployment['GEO'].replace(replace_dict)
#       YEAR    TOWN  UNEM_VALUE
# 1210  2021  Canada         8.0
# 1215  2021      NL        11.9
# 1220  2021     PEI         8.2

# %%
df_sorted.head(3)
# Out:
#    TOWN  CSI_Violent  Population
# 6    NU   570.633333       16621
# 7   NWT   410.475000       26803
# 12   YT   266.750000       25605

# %%
merged_df = pd.merge(df_unemployment, df_sorted, on='TOWN')
merged_df
# Out:
#    YEAR TOWN  UNEM_VALUE  CSI_Violent  Population
# 0  2021   NL        11.9   146.736842      291432
# 1  2021  PEI         8.2    55.900000       87970
# 2  2021   NS         8.5   108.580000      526340
# 3  2021   NB         9.6    91.223529      372659
# 4  2021   QC         6.7   184.625641     3608721
# 5  2021   ON         9.0    84.927097     8448323
# 6  2021   MB         7.8   236.287879      978996
# 7  2021   SK         6.4   259.722222      727177
# 8  2021   AB         7.7   135.815909     3323048
# 9  2021   BC         6.9   113.189535     3605446

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR         10 non-null     int64
#  1   TOWN         10 non-null     object
#  2   UNEM_VALUE   10 non-null     float64
#  3   CSI_Violent  10 non-null     float64
#  4   Population   10 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 480.0+ bytes

# %%
correlation = merged_df.corr(method="pearson")
sns.heatmap(correlation,annot=True)
plt.title('Correlation map')
#plt.xlabel('')
#plt.ylabel('')
plt.show()
# Out:
# <ipython-input-383-13b7d2d631f8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merged_df.corr(method="pearson")

# %%
sns.regplot(x='UNEM_VALUE', y='CSI_Violent', data=merged_df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})
plt.title('Unemployment. & Violence')
plt.xlabel('Unemployment')
plt.ylabel('Crimes/Violence')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(x='UNEM_VALUE', y='CSI_Violent', data=merged_df, hue='TOWN', palette='viridis')
plt.title('Unemployment & Violence by Town')
plt.xlabel('Unemployment')
plt.ylabel('Crimes/Violence')
plt.legend(title='Town')
plt.show()

# %%
# Crear rangos de desempleo
bins = [0, 5, 10, 15, 20, 25, 30]
labels = ['0-5', '6-10', '11-15', '16-20', '21-25', '26-30+']
merged_df['Unemployment_Range'] = pd.cut(merged_df['UNEM_VALUE'], bins=bins, labels=labels)

# Calcular el promedio de CSI_Violent por rango de desempleo
average_csi_by_unemployment = merged_df.groupby('Unemployment_Range')['CSI_Violent'].mean()

# Crear el gráfico de barras
plt.bar(average_csi_by_unemployment.index, average_csi_by_unemployment.values, color='blue')
plt.title('Average Violence by Unemployment Range')
plt.xlabel('Unemployment Range')
plt.ylabel('Average Crimes/Violence')
plt.show()

# %% [markdown]
# Source:
#
# Crimes:
# https://canadacrimeindex.com/crime-severity-index?sort=population&min_population=0&province=#data-source
#
# Unemployment rate:
# https://open.canada.ca/data/en/dataset/0f68117f-a98c-49c9-956f-2fa44baa18a4
